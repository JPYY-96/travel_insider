# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tpot import TPOTRegressor
from google.cloud import bigquery
from datetime import datetime
from sklearn.metrics import mean_absolute_error

# %%
# 📌 Set Up BigQuery Connection
PROJECT_ID = "travel-insider-452211"
DATASET_NAME = "travel_insider_dataset"
TABLE_NAME = "filtered_flights"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/home/sebastian/code/JPYY-96/travel_insider/raw_data/travel-insider-452211-181bd2eba48e.json"

# Initialize BigQuery Client
client = bigquery.Client()

# Initialize AutoML Model (TPOT)
auto_ml = TPOTRegressor(generations=5, population_size=20,  random_state=42)

# Parameters for querying data
chunk_size = 1000000  # Query 1 million rows at a time
offset = 0
total_rows = 16839840  # Total number of rows to process

# Initialize overall batch number
overall_batch_num = 0

# %%
# Loop over chunks of data
while offset < total_rows:
    print(f"\n[INFO] Querying data chunk {offset} to {offset + chunk_size}...")
    query = f"""
    SELECT * FROM `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}`
    LIMIT {chunk_size} OFFSET {offset}
    """
    chunk_data = client.query(query).to_dataframe()

    if chunk_data.empty:
        break

    # Feature Engineering
    chunk_data["searchDate"] = pd.to_datetime(chunk_data["searchDate"])
    chunk_data["flightDate"] = pd.to_datetime(chunk_data["flightDate"])
    chunk_data["days_to_flight"] = (chunk_data["flightDate"] - chunk_data["searchDate"]).dt.days
    chunk_data["day_of_week"] = chunk_data["flightDate"].dt.dayofweek
    chunk_data["is_weekend"] = (chunk_data["day_of_week"] >= 5).astype(int)
    chunk_data["is_holiday_season"] = chunk_data["flightDate"].dt.month.isin([6, 7, 12]).astype(int)
    chunk_data["days_to_flight_squared"] = chunk_data["days_to_flight"] ** 2
    chunk_data["days_to_flight_log"] = np.log1p(chunk_data["days_to_flight"])
    chunk_data = chunk_data[chunk_data["days_to_flight"] > 0]

    # Convert `isRefundable` to numeric
    chunk_data['isRefundable'] = chunk_data['isRefundable'].map({'Yes': 1, 'No': 0}).fillna(0).astype(int)

    # One-Hot Encode Categorical Features
    if overall_batch_num == 0:
        encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
        encoded_features = encoder.fit_transform(chunk_data[['startingAirport', 'destinationAirport', 'segmentsAirlineName']])
    else:
        encoded_features = encoder.transform(chunk_data[['startingAirport', 'destinationAirport', 'segmentsAirlineName']])

    encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out())

    feature_columns = ['days_to_flight', 'days_to_flight_squared', 'day_of_week', 'is_weekend', 'is_holiday_season',
                       'days_to_flight_log', 'seatsRemaining', 'isRefundable'] + list(encoded_df.columns)

    chunk_data = chunk_data.reset_index(drop=True)
    chunk_data = pd.concat([chunk_data, encoded_df], axis=1)

    # Select Features and Target
    X_chunk = chunk_data[feature_columns]
    y_chunk = chunk_data['totalFare']

    # Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(X_chunk, y_chunk, test_size=0.3, random_state=42)

    # Train AutoML Model (TPOT)
    if overall_batch_num == 0:
        auto_ml.fit(X_train, y_train)
    else:
        auto_ml.fit(X_train, y_train)  # TPOT automatically updates the model

    print(f"\n[INFO] Training completed for batch {overall_batch_num + 1}")
    overall_batch_num += 1

    # Increment offset for the next chunk
    offset += chunk_size
# Out:
# [INFO] Querying data chunk 0 to 1000000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       3 print(f"\n[INFO] Querying data chunk {offset} to {offset + chunk_size}...")
#       4 query = f"""
#       5 SELECT * FROM `{PROJECT_ID}.{DATASET_NAME}.{TABLE_NAME}`
#       6 LIMIT {chunk_size} OFFSET {offset}
#       7 """
# ----> 8 chunk_data = client.query(query).to_dataframe()
#      10 if chunk_data.empty:
#      11     break
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/bigquery/client.py:3502, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3491     return _job_helpers.query_jobs_query(
#    3492         self,
#    3493         query,
#    (...)
#    3499         job_retry,
#    3500     )
#    3501 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3502     return _job_helpers.query_jobs_insert(
#    3503         self,
#    3504         query,
#    3505         job_config,
#    3506         job_id,
#    3507         job_id_prefix,
#    3508         location,
#    3509         project,
#    3510         retry,
#    3511         timeout,
#    3512         job_retry,
#    3513     )
#    3514 else:
#    3515     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/bigquery/_job_helpers.py:181, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     178 if job_retry is not None:
#     179     do_query = google.cloud.bigquery.retry._DEFAULT_QUERY_JOB_INSERT_RETRY(do_query)
# --> 181 future = do_query()
#     183 # The future might be in a failed state now, but if it's
#     184 # unrecoverable, we'll find out when we ask for it's result, at which
#     185 # point, we may retry.
#     186 if not job_id_given:
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/bigquery/_job_helpers.py:137, in query_jobs_insert.<locals>.do_query()
#     134 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#     136 try:
# --> 137     query_job._begin(retry=retry, timeout=timeout)
#     138 except core_exceptions.Conflict as create_exc:
#     139     # The thought is if someone is providing their own job IDs and they get
#     140     # their job ID generation wrong, this could end up returning results for
#     141     # the wrong query. We thus only try to recover if job ID was not given.
#     142     if job_id_given:
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1383, in QueryJob._begin(self, client, retry, timeout)
#    1363 """API call:  begin the job via a POST request
#    1364
#    1365 See
#    (...)
#    1379     ValueError: If the job has already begun.
#    1380 """
#    1382 try:
# -> 1383     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1384 except exceptions.GoogleAPICallError as exc:
#    1385     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1386         message=exc.message, location=self.location, job_id=self.job_id
#    1387     )
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:746, in _AsyncJob._begin(self, client, retry, timeout)
#     743 # jobs.insert is idempotent because we ensure that every new
#     744 # job has an ID.
#     745 span_attributes = {"path": path}
# --> 746 api_response = client._call_api(
#     747     retry,
#     748     span_name="BigQuery.job.begin",
#     749     span_attributes=span_attributes,
#     750     job_ref=self,
#     751     method="POST",
#     752     path=path,
#     753     data=self.to_api_repr(),
#     754     timeout=timeout,
#     755 )
#     756 self._set_properties(api_response)
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/bigquery/client.py:843, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     839 if span_name is not None:
#     840     with create_span(
#     841         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     842     ):
# --> 843         return call()
#     845 return call()
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/google/auth/transport/requests.py:537, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     534 remaining_time = guard.remaining_timeout
#     536 with TimeoutGuard(remaining_time) as guard:
# --> 537     response = super(AuthorizedSession, self).request(
#     538         method,
#     539         url,
#     540         data=data,
#     541         headers=request_headers,
#     542         timeout=timeout,
#     543         **kwargs
#     544     )
#     545 remaining_time = guard.remaining_timeout
#     547 # If the response indicated that the credentials needed to be
#     548 # refreshed, then refresh the credentials and re-attempt the
#     549 # request.
#     550 # A stored token may expire between the time it is retrieved and
#     551 # the time the request is made, so we may need to try twice.
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/sebastian/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/asyncio/base_events.py", line 633, in run_until_complete
#     self.run_forever()
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/asyncio/base_events.py", line 1860, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sebastian/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/sebastian/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/sebastian/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/distributed/compatibility.py", line 239, in asyncio_run
#     _cancel_all_tasks(loop)
#   File "/home/sebastian/.pyenv/versions/3.10.6/envs/travel_insider/lib/python3.10/site-packages/distributed/compatibility.py", line 255, in _cancel_all_tasks
#     loop.run_until_complete(asyncio.gather(*to_cancel, return_exceptions=True))
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/asyncio/base_events.py", line 633, in run_until_complete
#     self.run_forever()
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/asyncio/base_events.py", line 1860, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/sebastian/.pyenv/versions/3.10.6/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt

# %%
# Final Evaluation
print("\n[INFO] Final Evaluation on Test Data...")
y_pred = auto_ml.predict(X_test)
mae_auto_ml = mean_absolute_error(y_test, y_pred)
mape_auto_ml = (mae_auto_ml / y_test.mean()) * 100
print(f"\n[RESULT] AutoML MAE: ${mae_auto_ml:.2f}, MAPE: {mape_auto_ml:.2f}%")

# Export Best Model
auto_ml.export('best_model_pipeline.py')
print("\n[INFO] Best Model Saved as best_model_pipeline.py")
# Out:
# ✅ [2025-03-13 21:32:35] Loaded 31818 rows (total: 1031818)
# ✅ [2025-03-13 21:32:42] Loaded 31818 rows (total: 1063636)
# ✅ [2025-03-13 21:32:50] Loaded 31818 rows (total: 1095454)
# ✅ [2025-03-13 21:32:57] Loaded 31818 rows (total: 1127272)
# ✅ [2025-03-13 21:33:05] Loaded 31818 rows (total: 1159090)
# ✅ [2025-03-13 21:33:13] Loaded 31818 rows (total: 1190908)
# ✅ [2025-03-13 21:33:21] Loaded 31818 rows (total: 1222726)
# ✅ [2025-03-13 21:33:28] Loaded 31818 rows (total: 1254544)
# ✅ [2025-03-13 21:33:36] Loaded 31818 rows (total: 1286362)
# ✅ [2025-03-13 21:33:44] Loaded 31818 rows (total: 1318180)
# ✅ [2025-03-13 21:33:52] Loaded 31818 rows (total: 1349998)
# ✅ [2025-03-13 21:33:59] Loaded 31818 rows (total: 1381816)
# ✅ [2025-03-13 21:34:07] Loaded 31818 rows (total: 1413634)
# ✅ [2025-03-13 21:34:15] Loaded 31818 rows (total: 1445452)
# ✅ [2025-03-13 21:34:23] Loaded 31818 rows (total: 1477270)
# ✅ [2025-03-13 21:34:31] Loaded 31818 rows (total: 1509088)
# ✅ [2025-03-13 21:34:38] Loaded 31818 rows (total: 1540906)
# ✅ [2025-03-13 21:34:45] Loaded 31818 rows (total: 1572724)
# ✅ [2025-03-13 21:34:53] Loaded 31818 rows (total: 1604542)
# ✅ [2025-03-13 21:35:00] Loaded 31818 rows (total: 1636360)
# ✅ [2025-03-13 21:35:08] Loaded 31818 rows (total: 1668178)
# ✅ [2025-03-13 21:35:15] Loaded 31818 rows (total: 1699996)
# ✅ [2025-03-13 21:35:23] Loaded 31818 rows (total: 1731814)
# ✅ [2025-03-13 21:35:30] Loaded 31818 rows (total: 1763632)
# ✅ [2025-03-13 21:35:38] Loaded 31818 rows (total: 1795450)
# ✅ [2025-03-13 21:35:46] Loaded 31818 rows (total: 1827268)
# ✅ [2025-03-13 21:35:53] Loaded 31818 rows (total: 1859086)
# ✅ [2025-03-13 21:36:01] Loaded 31818 rows (total: 1890904)
# ✅ [2025-03-13 21:36:09] Loaded 31818 rows (total: 1922722)
# ✅ [2025-03-13 21:36:16] Loaded 31818 rows (total: 1954540)
# ✅ [2025-03-13 21:36:24] Loaded 31818 rows (total: 1986358)
# ✅ [2025-03-13 21:36:27] Loaded 13642 rows (total: 2000000)
# ✅ [2025-03-13 21:36:28] Successfully loaded 2000000 rows from BigQuery!

# %%
# 📌 Convert Date Columns
data_query["searchDate"] = pd.to_datetime(data_query["searchDate"])
data_query["flightDate"] = pd.to_datetime(data_query["flightDate"])

# 📌 Feature Engineering
data_query["days_to_flight"] = (data_query["flightDate"] - data_query["searchDate"]).dt.days
data_query["day_of_week"] = data_query["flightDate"].dt.dayofweek
data_query["is_weekend"] = (data_query["day_of_week"] >= 5).astype(int)
data_query["is_holiday_season"] = data_query["flightDate"].dt.month.isin([6, 7, 12]).astype(int)
data_query["days_to_flight_squared"] = data_query["days_to_flight"] ** 2
data_query["flight_month"] = data_query["flightDate"].dt.month
data_query["flight_year"] = data_query["flightDate"].dt.year
data_query["search_month"] = data_query["searchDate"].dt.month
data_query["search_day"] = data_query["searchDate"].dt.day
data_query["days_to_flight_log"] = np.log1p(data_query["days_to_flight"])
data_query['isRefundable'] = data_query['isRefundable'].map({'true': 1, 'false': 0}).fillna(0).astype(int)

# Remove invalid rows
data_query = data_query[data_query["days_to_flight"] > 0]

# 📌 One-Hot Encode Categorical Features (Airports & Airlines)
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
encoded_features = encoder.fit_transform(data_query[['startingAirport', 'destinationAirport', 'segmentsAirlineName']])
encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out())

# 📌 Merge Encoded Data
data_query = data_query.reset_index(drop=True)
data_query = pd.concat([data_query, encoded_df], axis=1)

# %%
# 📌 Select Features
X = data_query[['days_to_flight', 'days_to_flight_squared', 'day_of_week', 'is_weekend', 'is_holiday_season',
                'flight_month', 'flight_year', 'search_month', 'search_day', 'days_to_flight_log',
                'seatsRemaining', 'isRefundable'] + list(encoded_df.columns)]
y = data_query['totalFare']

# 📌 Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 📌 Batch Training Function
def train_in_batches(model, X_train, y_train, batch_size=10000, n_iter=3):
    # Training in batches
    for i in range(n_iter):
        for start in range(0, X_train.shape[0], batch_size):
            end = min(start + batch_size, X_train.shape[0])
            X_batch, y_batch = X_train.iloc[start:end], y_train.iloc[start:end]
            model.fit(X_batch, y_batch, verbose=False)
            print(f"✅ Batch {i+1}, Training on rows {start} to {end}...")

# 📌 Initialize Models
xgb_model = XGBRegressor(
    n_estimators=500, learning_rate=0.05, max_depth=8,
    subsample=0.8, colsample_bytree=0.8, random_state=42
)


# 📌 Train Models in Batches
train_in_batches(xgb_model, X_train, y_train, batch_size=5000, n_iter=3)
# Out:
# ✅ Batch 1, Training on rows 0 to 5000...
# ✅ Batch 1, Training on rows 5000 to 10000...
# ✅ Batch 1, Training on rows 10000 to 15000...
# ✅ Batch 1, Training on rows 15000 to 20000...
# ✅ Batch 1, Training on rows 20000 to 25000...
# ✅ Batch 1, Training on rows 25000 to 30000...
# ✅ Batch 1, Training on rows 30000 to 35000...
# ✅ Batch 1, Training on rows 35000 to 40000...
# ✅ Batch 1, Training on rows 40000 to 45000...
# ✅ Batch 1, Training on rows 45000 to 50000...
# ✅ Batch 1, Training on rows 50000 to 55000...
# ✅ Batch 1, Training on rows 55000 to 60000...
# ✅ Batch 1, Training on rows 60000 to 65000...
# ✅ Batch 1, Training on rows 65000 to 70000...
# ✅ Batch 1, Training on rows 70000 to 75000...
# ✅ Batch 1, Training on rows 75000 to 80000...
# ✅ Batch 1, Training on rows 80000 to 85000...
# ✅ Batch 1, Training on rows 85000 to 90000...
# ✅ Batch 1, Training on rows 90000 to 95000...
# ✅ Batch 1, Training on rows 95000 to 100000...
# ✅ Batch 1, Training on rows 100000 to 105000...
# ✅ Batch 1, Training on rows 105000 to 110000...
# ✅ Batch 1, Training on rows 110000 to 115000...
# ✅ Batch 1, Training on rows 115000 to 120000...
# ✅ Batch 1, Training on rows 120000 to 125000...
# ✅ Batch 1, Training on rows 125000 to 130000...
# ✅ Batch 1, Training on rows 130000 to 135000...
# ✅ Batch 1, Training on rows 135000 to 140000...
# ✅ Batch 1, Training on rows 140000 to 145000...
# ✅ Batch 1, Training on rows 145000 to 150000...
# ✅ Batch 1, Training on rows 150000 to 155000...
# ✅ Batch 1, Training on rows 155000 to 160000...
# ✅ Batch 1, Training on rows 160000 to 165000...
# ✅ Batch 1, Training on rows 165000 to 170000...
# ✅ Batch 1, Training on rows 170000 to 175000...
# ✅ Batch 1, Training on rows 175000 to 180000...
# ✅ Batch 1, Training on rows 180000 to 185000...
# ✅ Batch 1, Training on rows 185000 to 190000...
# ✅ Batch 1, Training on rows 190000 to 195000...
# ✅ Batch 1, Training on rows 195000 to 200000...
# ✅ Batch 1, Training on rows 200000 to 205000...
# ✅ Batch 1, Training on rows 205000 to 210000...
# ✅ Batch 1, Training on rows 210000 to 215000...
# ✅ Batch 1, Training on rows 215000 to 220000...
# ✅ Batch 1, Training on rows 220000 to 225000...
# ✅ Batch 1, Training on rows 225000 to 230000...
# ✅ Batch 1, Training on rows 230000 to 235000...
# ✅ Batch 1, Training on rows 235000 to 240000...
# ✅ Batch 1, Training on rows 240000 to 245000...
# ✅ Batch 1, Training on rows 245000 to 250000...
# ✅ Batch 1, Training on rows 250000 to 255000...
# ✅ Batch 1, Training on rows 255000 to 260000...
# ✅ Batch 1, Training on rows 260000 to 265000...
# ✅ Batch 1, Training on rows 265000 to 270000...
# ✅ Batch 1, Training on rows 270000 to 275000...
# ✅ Batch 1, Training on rows 275000 to 280000...
# ✅ Batch 1, Training on rows 280000 to 285000...
# ✅ Batch 1, Training on rows 285000 to 290000...
# ✅ Batch 1, Training on rows 290000 to 295000...
# ✅ Batch 1, Training on rows 295000 to 300000...
# ✅ Batch 1, Training on rows 300000 to 305000...
# ✅ Batch 1, Training on rows 305000 to 310000...
# ✅ Batch 1, Training on rows 310000 to 315000...
# ✅ Batch 1, Training on rows 315000 to 320000...
# ✅ Batch 1, Training on rows 320000 to 325000...
# ✅ Batch 1, Training on rows 325000 to 330000...
# ✅ Batch 1, Training on rows 330000 to 335000...
# ✅ Batch 1, Training on rows 335000 to 340000...
# ✅ Batch 1, Training on rows 340000 to 345000...
# ✅ Batch 1, Training on rows 345000 to 350000...
# ✅ Batch 1, Training on rows 350000 to 355000...
# ✅ Batch 1, Training on rows 355000 to 360000...
# ✅ Batch 1, Training on rows 360000 to 365000...
# ✅ Batch 1, Training on rows 365000 to 370000...
# ✅ Batch 1, Training on rows 370000 to 375000...
# ✅ Batch 1, Training on rows 375000 to 380000...
# ✅ Batch 1, Training on rows 380000 to 385000...
# ✅ Batch 1, Training on rows 385000 to 390000...
# ✅ Batch 1, Training on rows 390000 to 395000...
# ✅ Batch 1, Training on rows 395000 to 400000...
# ✅ Batch 1, Training on rows 400000 to 405000...
# ✅ Batch 1, Training on rows 405000 to 410000...
# ✅ Batch 1, Training on rows 410000 to 415000...
# ✅ Batch 1, Training on rows 415000 to 420000...
# ✅ Batch 1, Training on rows 420000 to 425000...
# ✅ Batch 1, Training on rows 425000 to 430000...
# ✅ Batch 1, Training on rows 430000 to 435000...
# ✅ Batch 1, Training on rows 435000 to 440000...
# ✅ Batch 1, Training on rows 440000 to 445000...
# ✅ Batch 1, Training on rows 445000 to 450000...
# ✅ Batch 1, Training on rows 450000 to 455000...
# ✅ Batch 1, Training on rows 455000 to 460000...
# ✅ Batch 1, Training on rows 460000 to 465000...
# ✅ Batch 1, Training on rows 465000 to 470000...
# ✅ Batch 1, Training on rows 470000 to 475000...
# ✅ Batch 1, Training on rows 475000 to 480000...
# ✅ Batch 1, Training on rows 480000 to 485000...
# ✅ Batch 1, Training on rows 485000 to 490000...
# ✅ Batch 1, Training on rows 490000 to 495000...
# ✅ Batch 1, Training on rows 495000 to 500000...
# ✅ Batch 1, Training on rows 500000 to 505000...
# ✅ Batch 1, Training on rows 505000 to 510000...
# ✅ Batch 1, Training on rows 510000 to 515000...
# ✅ Batch 1, Training on rows 515000 to 520000...
# ✅ Batch 1, Training on rows 520000 to 525000...
# ✅ Batch 1, Training on rows 525000 to 530000...
# ✅ Batch 1, Training on rows 530000 to 535000...
# ✅ Batch 1, Training on rows 535000 to 540000...
# ✅ Batch 1, Training on rows 540000 to 545000...
# ✅ Batch 1, Training on rows 545000 to 550000...
# ✅ Batch 1, Training on rows 550000 to 555000...
# ✅ Batch 1, Training on rows 555000 to 560000...
# ✅ Batch 1, Training on rows 560000 to 565000...
# ✅ Batch 1, Training on rows 565000 to 570000...
# ✅ Batch 1, Training on rows 570000 to 575000...
# ✅ Batch 1, Training on rows 575000 to 580000...
# ✅ Batch 1, Training on rows 580000 to 585000...
# ✅ Batch 1, Training on rows 585000 to 590000...
# ✅ Batch 1, Training on rows 590000 to 595000...
# ✅ Batch 1, Training on rows 595000 to 600000...
# ✅ Batch 1, Training on rows 600000 to 605000...
# ✅ Batch 1, Training on rows 605000 to 610000...
# ✅ Batch 1, Training on rows 610000 to 615000...
# ✅ Batch 1, Training on rows 615000 to 620000...
# ✅ Batch 1, Training on rows 620000 to 625000...
# ✅ Batch 1, Training on rows 625000 to 630000...
# ✅ Batch 1, Training on rows 630000 to 635000...
# ✅ Batch 1, Training on rows 635000 to 640000...
# ✅ Batch 1, Training on rows 640000 to 645000...
# ✅ Batch 1, Training on rows 645000 to 650000...
# ✅ Batch 1, Training on rows 650000 to 655000...
# ✅ Batch 1, Training on rows 655000 to 660000...
# ✅ Batch 1, Training on rows 660000 to 665000...
# ✅ Batch 1, Training on rows 665000 to 670000...
# ✅ Batch 1, Training on rows 670000 to 675000...
# ✅ Batch 1, Training on rows 675000 to 680000...
# ✅ Batch 1, Training on rows 680000 to 685000...
# ✅ Batch 1, Training on rows 685000 to 690000...
# ✅ Batch 1, Training on rows 690000 to 695000...
# ✅ Batch 1, Training on rows 695000 to 700000...
# ✅ Batch 1, Training on rows 700000 to 705000...
# ✅ Batch 1, Training on rows 705000 to 710000...
# ✅ Batch 1, Training on rows 710000 to 715000...
# ✅ Batch 1, Training on rows 715000 to 720000...
# ✅ Batch 1, Training on rows 720000 to 725000...
# ✅ Batch 1, Training on rows 725000 to 730000...
# ✅ Batch 1, Training on rows 730000 to 735000...
# ✅ Batch 1, Training on rows 735000 to 740000...
# ✅ Batch 1, Training on rows 740000 to 745000...
# ✅ Batch 1, Training on rows 745000 to 750000...
# ✅ Batch 1, Training on rows 750000 to 755000...
# ✅ Batch 1, Training on rows 755000 to 760000...
# ✅ Batch 1, Training on rows 760000 to 765000...
# ✅ Batch 1, Training on rows 765000 to 770000...
# ✅ Batch 1, Training on rows 770000 to 775000...
# ✅ Batch 1, Training on rows 775000 to 780000...
# ✅ Batch 1, Training on rows 780000 to 785000...
# ✅ Batch 1, Training on rows 785000 to 790000...
# ✅ Batch 1, Training on rows 790000 to 795000...
# ✅ Batch 1, Training on rows 795000 to 800000...
# ✅ Batch 1, Training on rows 800000 to 805000...
# ✅ Batch 1, Training on rows 805000 to 810000...
# ✅ Batch 1, Training on rows 810000 to 815000...
# ✅ Batch 1, Training on rows 815000 to 820000...
# ✅ Batch 1, Training on rows 820000 to 825000...
# ✅ Batch 1, Training on rows 825000 to 830000...
# ✅ Batch 1, Training on rows 830000 to 835000...
# ✅ Batch 1, Training on rows 835000 to 840000...
# ✅ Batch 1, Training on rows 840000 to 845000...
# ✅ Batch 1, Training on rows 845000 to 850000...
# ✅ Batch 1, Training on rows 850000 to 855000...
# ✅ Batch 1, Training on rows 855000 to 860000...
# ✅ Batch 1, Training on rows 860000 to 865000...
# ✅ Batch 1, Training on rows 865000 to 870000...
# ✅ Batch 1, Training on rows 870000 to 875000...
# ✅ Batch 1, Training on rows 875000 to 880000...
# ✅ Batch 1, Training on rows 880000 to 885000...
# ✅ Batch 1, Training on rows 885000 to 890000...
# ✅ Batch 1, Training on rows 890000 to 895000...
# ✅ Batch 1, Training on rows 895000 to 900000...
# ✅ Batch 1, Training on rows 900000 to 905000...
# ✅ Batch 1, Training on rows 905000 to 910000...
# ✅ Batch 1, Training on rows 910000 to 915000...
# ✅ Batch 1, Training on rows 915000 to 920000...
# ✅ Batch 1, Training on rows 920000 to 925000...
# ✅ Batch 1, Training on rows 925000 to 930000...
# ✅ Batch 1, Training on rows 930000 to 935000...
# ✅ Batch 1, Training on rows 935000 to 940000...
# ✅ Batch 1, Training on rows 940000 to 945000...
# ✅ Batch 1, Training on rows 945000 to 950000...
# ✅ Batch 1, Training on rows 950000 to 955000...
# ✅ Batch 1, Training on rows 955000 to 960000...
# ✅ Batch 1, Training on rows 960000 to 965000...
# ✅ Batch 1, Training on rows 965000 to 970000...
# ✅ Batch 1, Training on rows 970000 to 975000...
# ✅ Batch 1, Training on rows 975000 to 980000...
# ✅ Batch 1, Training on rows 980000 to 985000...
# ✅ Batch 1, Training on rows 985000 to 990000...
# ✅ Batch 1, Training on rows 990000 to 995000...
# ✅ Batch 1, Training on rows 995000 to 1000000...
# ✅ Batch 1, Training on rows 1000000 to 1005000...
# ✅ Batch 1, Training on rows 1005000 to 1010000...
# ✅ Batch 1, Training on rows 1010000 to 1015000...
# ✅ Batch 1, Training on rows 1015000 to 1020000...
# ✅ Batch 1, Training on rows 1020000 to 1025000...
# ✅ Batch 1, Training on rows 1025000 to 1030000...
# ✅ Batch 1, Training on rows 1030000 to 1035000...
# ✅ Batch 1, Training on rows 1035000 to 1040000...
# ✅ Batch 1, Training on rows 1040000 to 1045000...
# ✅ Batch 1, Training on rows 1045000 to 1050000...
# ✅ Batch 1, Training on rows 1050000 to 1055000...
# ✅ Batch 1, Training on rows 1055000 to 1060000...
# ✅ Batch 1, Training on rows 1060000 to 1065000...
# ✅ Batch 1, Training on rows 1065000 to 1070000...
# ✅ Batch 1, Training on rows 1070000 to 1075000...
# ✅ Batch 1, Training on rows 1075000 to 1080000...
# ✅ Batch 1, Training on rows 1080000 to 1085000...
# ✅ Batch 1, Training on rows 1085000 to 1090000...
# ✅ Batch 1, Training on rows 1090000 to 1095000...
# ✅ Batch 1, Training on rows 1095000 to 1100000...
# ✅ Batch 1, Training on rows 1100000 to 1105000...
# ✅ Batch 1, Training on rows 1105000 to 1110000...
# ✅ Batch 1, Training on rows 1110000 to 1115000...
# ✅ Batch 1, Training on rows 1115000 to 1120000...
# ✅ Batch 1, Training on rows 1120000 to 1125000...
# ✅ Batch 1, Training on rows 1125000 to 1130000...
# ✅ Batch 1, Training on rows 1130000 to 1135000...
# ✅ Batch 1, Training on rows 1135000 to 1140000...
# ✅ Batch 1, Training on rows 1140000 to 1145000...
# ✅ Batch 1, Training on rows 1145000 to 1150000...
# ✅ Batch 1, Training on rows 1150000 to 1155000...
# ✅ Batch 1, Training on rows 1155000 to 1160000...
# ✅ Batch 1, Training on rows 1160000 to 1165000...
# ✅ Batch 1, Training on rows 1165000 to 1170000...
# ✅ Batch 1, Training on rows 1170000 to 1175000...
# ✅ Batch 1, Training on rows 1175000 to 1180000...
# ✅ Batch 1, Training on rows 1180000 to 1185000...
# ✅ Batch 1, Training on rows 1185000 to 1190000...
# ✅ Batch 1, Training on rows 1190000 to 1195000...
# ✅ Batch 1, Training on rows 1195000 to 1200000...
# ✅ Batch 1, Training on rows 1200000 to 1205000...
# ✅ Batch 1, Training on rows 1205000 to 1210000...
# ✅ Batch 1, Training on rows 1210000 to 1215000...
# ✅ Batch 1, Training on rows 1215000 to 1220000...
# ✅ Batch 1, Training on rows 1220000 to 1225000...
# ✅ Batch 1, Training on rows 1225000 to 1230000...
# ✅ Batch 1, Training on rows 1230000 to 1235000...
# ✅ Batch 1, Training on rows 1235000 to 1240000...
# ✅ Batch 1, Training on rows 1240000 to 1245000...
# ✅ Batch 1, Training on rows 1245000 to 1250000...
# ✅ Batch 1, Training on rows 1250000 to 1255000...
# ✅ Batch 1, Training on rows 1255000 to 1260000...
# ✅ Batch 1, Training on rows 1260000 to 1265000...
# ✅ Batch 1, Training on rows 1265000 to 1270000...
# ✅ Batch 1, Training on rows 1270000 to 1275000...
# ✅ Batch 1, Training on rows 1275000 to 1280000...
# ✅ Batch 1, Training on rows 1280000 to 1285000...
# ✅ Batch 1, Training on rows 1285000 to 1290000...
# ✅ Batch 1, Training on rows 1290000 to 1295000...
# ✅ Batch 1, Training on rows 1295000 to 1300000...
# ✅ Batch 1, Training on rows 1300000 to 1305000...
# ✅ Batch 1, Training on rows 1305000 to 1310000...
# ✅ Batch 1, Training on rows 1310000 to 1315000...
# ✅ Batch 1, Training on rows 1315000 to 1320000...
# ✅ Batch 1, Training on rows 1320000 to 1325000...
# ✅ Batch 1, Training on rows 1325000 to 1330000...
# ✅ Batch 1, Training on rows 1330000 to 1335000...
# ✅ Batch 1, Training on rows 1335000 to 1340000...
# ✅ Batch 1, Training on rows 1340000 to 1345000...
# ✅ Batch 1, Training on rows 1345000 to 1350000...
# ✅ Batch 1, Training on rows 1350000 to 1355000...
# ✅ Batch 1, Training on rows 1355000 to 1360000...
# ✅ Batch 1, Training on rows 1360000 to 1365000...
# ✅ Batch 1, Training on rows 1365000 to 1370000...
# ✅ Batch 1, Training on rows 1370000 to 1375000...
# ✅ Batch 1, Training on rows 1375000 to 1380000...
# ✅ Batch 1, Training on rows 1380000 to 1385000...
# ✅ Batch 1, Training on rows 1385000 to 1390000...
# ✅ Batch 1, Training on rows 1390000 to 1395000...
# ✅ Batch 1, Training on rows 1395000 to 1400000...
# ✅ Batch 2, Training on rows 0 to 5000...
# ✅ Batch 2, Training on rows 5000 to 10000...
# ✅ Batch 2, Training on rows 10000 to 15000...
# ✅ Batch 2, Training on rows 15000 to 20000...
# ✅ Batch 2, Training on rows 20000 to 25000...
# ✅ Batch 2, Training on rows 25000 to 30000...
# ✅ Batch 2, Training on rows 30000 to 35000...
# ✅ Batch 2, Training on rows 35000 to 40000...
# ✅ Batch 2, Training on rows 40000 to 45000...
# ✅ Batch 2, Training on rows 45000 to 50000...
# ✅ Batch 2, Training on rows 50000 to 55000...
# ✅ Batch 2, Training on rows 55000 to 60000...
# ✅ Batch 2, Training on rows 60000 to 65000...
# ✅ Batch 2, Training on rows 65000 to 70000...
# ✅ Batch 2, Training on rows 70000 to 75000...
# ✅ Batch 2, Training on rows 75000 to 80000...
# ✅ Batch 2, Training on rows 80000 to 85000...
# ✅ Batch 2, Training on rows 85000 to 90000...
# ✅ Batch 2, Training on rows 90000 to 95000...
# ✅ Batch 2, Training on rows 95000 to 100000...
# ✅ Batch 2, Training on rows 100000 to 105000...
# ✅ Batch 2, Training on rows 105000 to 110000...
# ✅ Batch 2, Training on rows 110000 to 115000...
# ✅ Batch 2, Training on rows 115000 to 120000...
# ✅ Batch 2, Training on rows 120000 to 125000...
# ✅ Batch 2, Training on rows 125000 to 130000...
# ✅ Batch 2, Training on rows 130000 to 135000...
# ✅ Batch 2, Training on rows 135000 to 140000...
# ✅ Batch 2, Training on rows 140000 to 145000...
# ✅ Batch 2, Training on rows 145000 to 150000...
# ✅ Batch 2, Training on rows 150000 to 155000...
# ✅ Batch 2, Training on rows 155000 to 160000...
# ✅ Batch 2, Training on rows 160000 to 165000...
# ✅ Batch 2, Training on rows 165000 to 170000...
# ✅ Batch 2, Training on rows 170000 to 175000...
# ✅ Batch 2, Training on rows 175000 to 180000...
# ✅ Batch 2, Training on rows 180000 to 185000...
# ✅ Batch 2, Training on rows 185000 to 190000...
# ✅ Batch 2, Training on rows 190000 to 195000...
# ✅ Batch 2, Training on rows 195000 to 200000...
# ✅ Batch 2, Training on rows 200000 to 205000...
# ✅ Batch 2, Training on rows 205000 to 210000...
# ✅ Batch 2, Training on rows 210000 to 215000...
# ✅ Batch 2, Training on rows 215000 to 220000...
# ✅ Batch 2, Training on rows 220000 to 225000...
# ✅ Batch 2, Training on rows 225000 to 230000...
# ✅ Batch 2, Training on rows 230000 to 235000...
# ✅ Batch 2, Training on rows 235000 to 240000...
# ✅ Batch 2, Training on rows 240000 to 245000...
# ✅ Batch 2, Training on rows 245000 to 250000...
# ✅ Batch 2, Training on rows 250000 to 255000...
# ✅ Batch 2, Training on rows 255000 to 260000...
# ✅ Batch 2, Training on rows 260000 to 265000...
# ✅ Batch 2, Training on rows 265000 to 270000...
# ✅ Batch 2, Training on rows 270000 to 275000...
# ✅ Batch 2, Training on rows 275000 to 280000...
# ✅ Batch 2, Training on rows 280000 to 285000...
# ✅ Batch 2, Training on rows 285000 to 290000...
# ✅ Batch 2, Training on rows 290000 to 295000...
# ✅ Batch 2, Training on rows 295000 to 300000...
# ✅ Batch 2, Training on rows 300000 to 305000...
# ✅ Batch 2, Training on rows 305000 to 310000...
# ✅ Batch 2, Training on rows 310000 to 315000...
# ✅ Batch 2, Training on rows 315000 to 320000...
# ✅ Batch 2, Training on rows 320000 to 325000...
# ✅ Batch 2, Training on rows 325000 to 330000...
# ✅ Batch 2, Training on rows 330000 to 335000...
# ✅ Batch 2, Training on rows 335000 to 340000...
# ✅ Batch 2, Training on rows 340000 to 345000...
# ✅ Batch 2, Training on rows 345000 to 350000...
# ✅ Batch 2, Training on rows 350000 to 355000...
# ✅ Batch 2, Training on rows 355000 to 360000...
# ✅ Batch 2, Training on rows 360000 to 365000...
# ✅ Batch 2, Training on rows 365000 to 370000...
# ✅ Batch 2, Training on rows 370000 to 375000...
# ✅ Batch 2, Training on rows 375000 to 380000...
# ✅ Batch 2, Training on rows 380000 to 385000...
# ✅ Batch 2, Training on rows 385000 to 390000...
# ✅ Batch 2, Training on rows 390000 to 395000...
# ✅ Batch 2, Training on rows 395000 to 400000...
# ✅ Batch 2, Training on rows 400000 to 405000...
# ✅ Batch 2, Training on rows 405000 to 410000...
# ✅ Batch 2, Training on rows 410000 to 415000...
# ✅ Batch 2, Training on rows 415000 to 420000...
# ✅ Batch 2, Training on rows 420000 to 425000...
# ✅ Batch 2, Training on rows 425000 to 430000...
# ✅ Batch 2, Training on rows 430000 to 435000...
# ✅ Batch 2, Training on rows 435000 to 440000...
# ✅ Batch 2, Training on rows 440000 to 445000...
# ✅ Batch 2, Training on rows 445000 to 450000...
# ✅ Batch 2, Training on rows 450000 to 455000...
# ✅ Batch 2, Training on rows 455000 to 460000...
# ✅ Batch 2, Training on rows 460000 to 465000...
# ✅ Batch 2, Training on rows 465000 to 470000...
# ✅ Batch 2, Training on rows 470000 to 475000...
# ✅ Batch 2, Training on rows 475000 to 480000...
# ✅ Batch 2, Training on rows 480000 to 485000...
# ✅ Batch 2, Training on rows 485000 to 490000...
# ✅ Batch 2, Training on rows 490000 to 495000...
# ✅ Batch 2, Training on rows 495000 to 500000...
# ✅ Batch 2, Training on rows 500000 to 505000...
# ✅ Batch 2, Training on rows 505000 to 510000...
# ✅ Batch 2, Training on rows 510000 to 515000...
# ✅ Batch 2, Training on rows 515000 to 520000...
# ✅ Batch 2, Training on rows 520000 to 525000...
# ✅ Batch 2, Training on rows 525000 to 530000...
# ✅ Batch 2, Training on rows 530000 to 535000...
# ✅ Batch 2, Training on rows 535000 to 540000...
# ✅ Batch 2, Training on rows 540000 to 545000...
# ✅ Batch 2, Training on rows 545000 to 550000...
# ✅ Batch 2, Training on rows 550000 to 555000...
# ✅ Batch 2, Training on rows 555000 to 560000...
# ✅ Batch 2, Training on rows 560000 to 565000...
# ✅ Batch 2, Training on rows 565000 to 570000...
# ✅ Batch 2, Training on rows 570000 to 575000...
# ✅ Batch 2, Training on rows 575000 to 580000...
# ✅ Batch 2, Training on rows 580000 to 585000...
# ✅ Batch 2, Training on rows 585000 to 590000...
# ✅ Batch 2, Training on rows 590000 to 595000...
# ✅ Batch 2, Training on rows 595000 to 600000...
# ✅ Batch 2, Training on rows 600000 to 605000...
# ✅ Batch 2, Training on rows 605000 to 610000...
# ✅ Batch 2, Training on rows 610000 to 615000...
# ✅ Batch 2, Training on rows 615000 to 620000...
# ✅ Batch 2, Training on rows 620000 to 625000...
# ✅ Batch 2, Training on rows 625000 to 630000...
# ✅ Batch 2, Training on rows 630000 to 635000...
# ✅ Batch 2, Training on rows 635000 to 640000...
# ✅ Batch 2, Training on rows 640000 to 645000...
# ✅ Batch 2, Training on rows 645000 to 650000...
# ✅ Batch 2, Training on rows 650000 to 655000...
# ✅ Batch 2, Training on rows 655000 to 660000...
# ✅ Batch 2, Training on rows 660000 to 665000...
# ✅ Batch 2, Training on rows 665000 to 670000...
# ✅ Batch 2, Training on rows 670000 to 675000...
# ✅ Batch 2, Training on rows 675000 to 680000...
# ✅ Batch 2, Training on rows 680000 to 685000...
# ✅ Batch 2, Training on rows 685000 to 690000...
# ✅ Batch 2, Training on rows 690000 to 695000...
# ✅ Batch 2, Training on rows 695000 to 700000...
# ✅ Batch 2, Training on rows 700000 to 705000...
# ✅ Batch 2, Training on rows 705000 to 710000...
# ✅ Batch 2, Training on rows 710000 to 715000...
# ✅ Batch 2, Training on rows 715000 to 720000...
# ✅ Batch 2, Training on rows 720000 to 725000...
# ✅ Batch 2, Training on rows 725000 to 730000...
# ✅ Batch 2, Training on rows 730000 to 735000...
# ✅ Batch 2, Training on rows 735000 to 740000...
# ✅ Batch 2, Training on rows 740000 to 745000...
# ✅ Batch 2, Training on rows 745000 to 750000...
# ✅ Batch 2, Training on rows 750000 to 755000...
# ✅ Batch 2, Training on rows 755000 to 760000...
# ✅ Batch 2, Training on rows 760000 to 765000...
# ✅ Batch 2, Training on rows 765000 to 770000...
# ✅ Batch 2, Training on rows 770000 to 775000...
# ✅ Batch 2, Training on rows 775000 to 780000...
# ✅ Batch 2, Training on rows 780000 to 785000...
# ✅ Batch 2, Training on rows 785000 to 790000...
# ✅ Batch 2, Training on rows 790000 to 795000...
# ✅ Batch 2, Training on rows 795000 to 800000...
# ✅ Batch 2, Training on rows 800000 to 805000...
# ✅ Batch 2, Training on rows 805000 to 810000...
# ✅ Batch 2, Training on rows 810000 to 815000...
# ✅ Batch 2, Training on rows 815000 to 820000...
# ✅ Batch 2, Training on rows 820000 to 825000...
# ✅ Batch 2, Training on rows 825000 to 830000...
# ✅ Batch 2, Training on rows 830000 to 835000...
# ✅ Batch 2, Training on rows 835000 to 840000...
# ✅ Batch 2, Training on rows 840000 to 845000...
# ✅ Batch 2, Training on rows 845000 to 850000...
# ✅ Batch 2, Training on rows 850000 to 855000...
# ✅ Batch 2, Training on rows 855000 to 860000...
# ✅ Batch 2, Training on rows 860000 to 865000...
# ✅ Batch 2, Training on rows 865000 to 870000...
# ✅ Batch 2, Training on rows 870000 to 875000...
# ✅ Batch 2, Training on rows 875000 to 880000...
# ✅ Batch 2, Training on rows 880000 to 885000...
# ✅ Batch 2, Training on rows 885000 to 890000...
# ✅ Batch 2, Training on rows 890000 to 895000...
# ✅ Batch 2, Training on rows 895000 to 900000...
# ✅ Batch 2, Training on rows 900000 to 905000...
# ✅ Batch 2, Training on rows 905000 to 910000...
# ✅ Batch 2, Training on rows 910000 to 915000...
# ✅ Batch 2, Training on rows 915000 to 920000...
# ✅ Batch 2, Training on rows 920000 to 925000...
# ✅ Batch 2, Training on rows 925000 to 930000...
# ✅ Batch 2, Training on rows 930000 to 935000...
# ✅ Batch 2, Training on rows 935000 to 940000...
# ✅ Batch 2, Training on rows 940000 to 945000...
# ✅ Batch 2, Training on rows 945000 to 950000...
# ✅ Batch 2, Training on rows 950000 to 955000...
# ✅ Batch 2, Training on rows 955000 to 960000...
# ✅ Batch 2, Training on rows 960000 to 965000...
# ✅ Batch 2, Training on rows 965000 to 970000...
# ✅ Batch 2, Training on rows 970000 to 975000...
# ✅ Batch 2, Training on rows 975000 to 980000...
# ✅ Batch 2, Training on rows 980000 to 985000...
# ✅ Batch 2, Training on rows 985000 to 990000...
# ✅ Batch 2, Training on rows 990000 to 995000...
# ✅ Batch 2, Training on rows 995000 to 1000000...
# ✅ Batch 2, Training on rows 1000000 to 1005000...
# ✅ Batch 2, Training on rows 1005000 to 1010000...
# ✅ Batch 2, Training on rows 1010000 to 1015000...
# ✅ Batch 2, Training on rows 1015000 to 1020000...
# ✅ Batch 2, Training on rows 1020000 to 1025000...
# ✅ Batch 2, Training on rows 1025000 to 1030000...
# ✅ Batch 2, Training on rows 1030000 to 1035000...
# ✅ Batch 2, Training on rows 1035000 to 1040000...
# ✅ Batch 2, Training on rows 1040000 to 1045000...
# ✅ Batch 2, Training on rows 1045000 to 1050000...
# ✅ Batch 2, Training on rows 1050000 to 1055000...
# ✅ Batch 2, Training on rows 1055000 to 1060000...
# ✅ Batch 2, Training on rows 1060000 to 1065000...
# ✅ Batch 2, Training on rows 1065000 to 1070000...
# ✅ Batch 2, Training on rows 1070000 to 1075000...
# ✅ Batch 2, Training on rows 1075000 to 1080000...
# ✅ Batch 2, Training on rows 1080000 to 1085000...
# ✅ Batch 2, Training on rows 1085000 to 1090000...
# ✅ Batch 2, Training on rows 1090000 to 1095000...
# ✅ Batch 2, Training on rows 1095000 to 1100000...
# ✅ Batch 2, Training on rows 1100000 to 1105000...
# ✅ Batch 2, Training on rows 1105000 to 1110000...
# ✅ Batch 2, Training on rows 1110000 to 1115000...
# ✅ Batch 2, Training on rows 1115000 to 1120000...
# ✅ Batch 2, Training on rows 1120000 to 1125000...
# ✅ Batch 2, Training on rows 1125000 to 1130000...
# ✅ Batch 2, Training on rows 1130000 to 1135000...
# ✅ Batch 2, Training on rows 1135000 to 1140000...
# ✅ Batch 2, Training on rows 1140000 to 1145000...
# ✅ Batch 2, Training on rows 1145000 to 1150000...
# ✅ Batch 2, Training on rows 1150000 to 1155000...
# ✅ Batch 2, Training on rows 1155000 to 1160000...
# ✅ Batch 2, Training on rows 1160000 to 1165000...
# ✅ Batch 2, Training on rows 1165000 to 1170000...
# ✅ Batch 2, Training on rows 1170000 to 1175000...
# ✅ Batch 2, Training on rows 1175000 to 1180000...
# ✅ Batch 2, Training on rows 1180000 to 1185000...
# ✅ Batch 2, Training on rows 1185000 to 1190000...
# ✅ Batch 2, Training on rows 1190000 to 1195000...
# ✅ Batch 2, Training on rows 1195000 to 1200000...
# ✅ Batch 2, Training on rows 1200000 to 1205000...
# ✅ Batch 2, Training on rows 1205000 to 1210000...
# ✅ Batch 2, Training on rows 1210000 to 1215000...
# ✅ Batch 2, Training on rows 1215000 to 1220000...
# ✅ Batch 2, Training on rows 1220000 to 1225000...
# ✅ Batch 2, Training on rows 1225000 to 1230000...
# ✅ Batch 2, Training on rows 1230000 to 1235000...
# ✅ Batch 2, Training on rows 1235000 to 1240000...
# ✅ Batch 2, Training on rows 1240000 to 1245000...
# ✅ Batch 2, Training on rows 1245000 to 1250000...
# ✅ Batch 2, Training on rows 1250000 to 1255000...
# ✅ Batch 2, Training on rows 1255000 to 1260000...
# ✅ Batch 2, Training on rows 1260000 to 1265000...
# ✅ Batch 2, Training on rows 1265000 to 1270000...
# ✅ Batch 2, Training on rows 1270000 to 1275000...
# ✅ Batch 2, Training on rows 1275000 to 1280000...
# ✅ Batch 2, Training on rows 1280000 to 1285000...
# ✅ Batch 2, Training on rows 1285000 to 1290000...
# ✅ Batch 2, Training on rows 1290000 to 1295000...
# ✅ Batch 2, Training on rows 1295000 to 1300000...
# ✅ Batch 2, Training on rows 1300000 to 1305000...
# ✅ Batch 2, Training on rows 1305000 to 1310000...
# ✅ Batch 2, Training on rows 1310000 to 1315000...
# ✅ Batch 2, Training on rows 1315000 to 1320000...
# ✅ Batch 2, Training on rows 1320000 to 1325000...
# ✅ Batch 2, Training on rows 1325000 to 1330000...
# ✅ Batch 2, Training on rows 1330000 to 1335000...
# ✅ Batch 2, Training on rows 1335000 to 1340000...
# ✅ Batch 2, Training on rows 1340000 to 1345000...
# ✅ Batch 2, Training on rows 1345000 to 1350000...
# ✅ Batch 2, Training on rows 1350000 to 1355000...
# ✅ Batch 2, Training on rows 1355000 to 1360000...
# ✅ Batch 2, Training on rows 1360000 to 1365000...
# ✅ Batch 2, Training on rows 1365000 to 1370000...
# ✅ Batch 2, Training on rows 1370000 to 1375000...
# ✅ Batch 2, Training on rows 1375000 to 1380000...
# ✅ Batch 2, Training on rows 1380000 to 1385000...
# ✅ Batch 2, Training on rows 1385000 to 1390000...
# ✅ Batch 2, Training on rows 1390000 to 1395000...
# ✅ Batch 2, Training on rows 1395000 to 1400000...
# ✅ Batch 3, Training on rows 0 to 5000...
# ✅ Batch 3, Training on rows 5000 to 10000...
# ✅ Batch 3, Training on rows 10000 to 15000...
# ✅ Batch 3, Training on rows 15000 to 20000...
# ✅ Batch 3, Training on rows 20000 to 25000...
# ✅ Batch 3, Training on rows 25000 to 30000...
# ✅ Batch 3, Training on rows 30000 to 35000...
# ✅ Batch 3, Training on rows 35000 to 40000...
# ✅ Batch 3, Training on rows 40000 to 45000...
# ✅ Batch 3, Training on rows 45000 to 50000...
# ✅ Batch 3, Training on rows 50000 to 55000...
# ✅ Batch 3, Training on rows 55000 to 60000...
# ✅ Batch 3, Training on rows 60000 to 65000...
# ✅ Batch 3, Training on rows 65000 to 70000...
# ✅ Batch 3, Training on rows 70000 to 75000...
# ✅ Batch 3, Training on rows 75000 to 80000...
# ✅ Batch 3, Training on rows 80000 to 85000...
# ✅ Batch 3, Training on rows 85000 to 90000...
# ✅ Batch 3, Training on rows 90000 to 95000...
# ✅ Batch 3, Training on rows 95000 to 100000...
# ✅ Batch 3, Training on rows 100000 to 105000...
# ✅ Batch 3, Training on rows 105000 to 110000...
# ✅ Batch 3, Training on rows 110000 to 115000...
# ✅ Batch 3, Training on rows 115000 to 120000...
# ✅ Batch 3, Training on rows 120000 to 125000...
# ✅ Batch 3, Training on rows 125000 to 130000...
# ✅ Batch 3, Training on rows 130000 to 135000...
# ✅ Batch 3, Training on rows 135000 to 140000...
# ✅ Batch 3, Training on rows 140000 to 145000...
# ✅ Batch 3, Training on rows 145000 to 150000...
# ✅ Batch 3, Training on rows 150000 to 155000...
# ✅ Batch 3, Training on rows 155000 to 160000...
# ✅ Batch 3, Training on rows 160000 to 165000...
# ✅ Batch 3, Training on rows 165000 to 170000...
# ✅ Batch 3, Training on rows 170000 to 175000...
# ✅ Batch 3, Training on rows 175000 to 180000...
# ✅ Batch 3, Training on rows 180000 to 185000...
# ✅ Batch 3, Training on rows 185000 to 190000...
# ✅ Batch 3, Training on rows 190000 to 195000...
# ✅ Batch 3, Training on rows 195000 to 200000...
# ✅ Batch 3, Training on rows 200000 to 205000...
# ✅ Batch 3, Training on rows 205000 to 210000...
# ✅ Batch 3, Training on rows 210000 to 215000...
# ✅ Batch 3, Training on rows 215000 to 220000...
# ✅ Batch 3, Training on rows 220000 to 225000...
# ✅ Batch 3, Training on rows 225000 to 230000...
# ✅ Batch 3, Training on rows 230000 to 235000...
# ✅ Batch 3, Training on rows 235000 to 240000...
# ✅ Batch 3, Training on rows 240000 to 245000...
# ✅ Batch 3, Training on rows 245000 to 250000...
# ✅ Batch 3, Training on rows 250000 to 255000...
# ✅ Batch 3, Training on rows 255000 to 260000...
# ✅ Batch 3, Training on rows 260000 to 265000...
# ✅ Batch 3, Training on rows 265000 to 270000...
# ✅ Batch 3, Training on rows 270000 to 275000...
# ✅ Batch 3, Training on rows 275000 to 280000...
# ✅ Batch 3, Training on rows 280000 to 285000...
# ✅ Batch 3, Training on rows 285000 to 290000...
# ✅ Batch 3, Training on rows 290000 to 295000...
# ✅ Batch 3, Training on rows 295000 to 300000...
# ✅ Batch 3, Training on rows 300000 to 305000...
# ✅ Batch 3, Training on rows 305000 to 310000...
# ✅ Batch 3, Training on rows 310000 to 315000...
# ✅ Batch 3, Training on rows 315000 to 320000...
# ✅ Batch 3, Training on rows 320000 to 325000...
# ✅ Batch 3, Training on rows 325000 to 330000...
# ✅ Batch 3, Training on rows 330000 to 335000...
# ✅ Batch 3, Training on rows 335000 to 340000...
# ✅ Batch 3, Training on rows 340000 to 345000...
# ✅ Batch 3, Training on rows 345000 to 350000...
# ✅ Batch 3, Training on rows 350000 to 355000...
# ✅ Batch 3, Training on rows 355000 to 360000...
# ✅ Batch 3, Training on rows 360000 to 365000...
# ✅ Batch 3, Training on rows 365000 to 370000...
# ✅ Batch 3, Training on rows 370000 to 375000...
# ✅ Batch 3, Training on rows 375000 to 380000...
# ✅ Batch 3, Training on rows 380000 to 385000...
# ✅ Batch 3, Training on rows 385000 to 390000...
# ✅ Batch 3, Training on rows 390000 to 395000...
# ✅ Batch 3, Training on rows 395000 to 400000...
# ✅ Batch 3, Training on rows 400000 to 405000...
# ✅ Batch 3, Training on rows 405000 to 410000...
# ✅ Batch 3, Training on rows 410000 to 415000...
# ✅ Batch 3, Training on rows 415000 to 420000...
# ✅ Batch 3, Training on rows 420000 to 425000...
# ✅ Batch 3, Training on rows 425000 to 430000...
# ✅ Batch 3, Training on rows 430000 to 435000...
# ✅ Batch 3, Training on rows 435000 to 440000...
# ✅ Batch 3, Training on rows 440000 to 445000...
# ✅ Batch 3, Training on rows 445000 to 450000...
# ✅ Batch 3, Training on rows 450000 to 455000...
# ✅ Batch 3, Training on rows 455000 to 460000...
# ✅ Batch 3, Training on rows 460000 to 465000...
# ✅ Batch 3, Training on rows 465000 to 470000...
# ✅ Batch 3, Training on rows 470000 to 475000...
# ✅ Batch 3, Training on rows 475000 to 480000...
# ✅ Batch 3, Training on rows 480000 to 485000...
# ✅ Batch 3, Training on rows 485000 to 490000...
# ✅ Batch 3, Training on rows 490000 to 495000...
# ✅ Batch 3, Training on rows 495000 to 500000...
# ✅ Batch 3, Training on rows 500000 to 505000...
# ✅ Batch 3, Training on rows 505000 to 510000...
# ✅ Batch 3, Training on rows 510000 to 515000...
# ✅ Batch 3, Training on rows 515000 to 520000...
# ✅ Batch 3, Training on rows 520000 to 525000...
# ✅ Batch 3, Training on rows 525000 to 530000...
# ✅ Batch 3, Training on rows 530000 to 535000...
# ✅ Batch 3, Training on rows 535000 to 540000...
# ✅ Batch 3, Training on rows 540000 to 545000...
# ✅ Batch 3, Training on rows 545000 to 550000...
# ✅ Batch 3, Training on rows 550000 to 555000...
# ✅ Batch 3, Training on rows 555000 to 560000...
# ✅ Batch 3, Training on rows 560000 to 565000...
# ✅ Batch 3, Training on rows 565000 to 570000...
# ✅ Batch 3, Training on rows 570000 to 575000...
# ✅ Batch 3, Training on rows 575000 to 580000...
# ✅ Batch 3, Training on rows 580000 to 585000...
# ✅ Batch 3, Training on rows 585000 to 590000...
# ✅ Batch 3, Training on rows 590000 to 595000...
# ✅ Batch 3, Training on rows 595000 to 600000...
# ✅ Batch 3, Training on rows 600000 to 605000...
# ✅ Batch 3, Training on rows 605000 to 610000...
# ✅ Batch 3, Training on rows 610000 to 615000...
# ✅ Batch 3, Training on rows 615000 to 620000...
# ✅ Batch 3, Training on rows 620000 to 625000...
# ✅ Batch 3, Training on rows 625000 to 630000...
# ✅ Batch 3, Training on rows 630000 to 635000...
# ✅ Batch 3, Training on rows 635000 to 640000...
# ✅ Batch 3, Training on rows 640000 to 645000...
# ✅ Batch 3, Training on rows 645000 to 650000...
# ✅ Batch 3, Training on rows 650000 to 655000...
# ✅ Batch 3, Training on rows 655000 to 660000...
# ✅ Batch 3, Training on rows 660000 to 665000...
# ✅ Batch 3, Training on rows 665000 to 670000...
# ✅ Batch 3, Training on rows 670000 to 675000...
# ✅ Batch 3, Training on rows 675000 to 680000...
# ✅ Batch 3, Training on rows 680000 to 685000...
# ✅ Batch 3, Training on rows 685000 to 690000...
# ✅ Batch 3, Training on rows 690000 to 695000...
# ✅ Batch 3, Training on rows 695000 to 700000...
# ✅ Batch 3, Training on rows 700000 to 705000...
# ✅ Batch 3, Training on rows 705000 to 710000...
# ✅ Batch 3, Training on rows 710000 to 715000...
# ✅ Batch 3, Training on rows 715000 to 720000...
# ✅ Batch 3, Training on rows 720000 to 725000...
# ✅ Batch 3, Training on rows 725000 to 730000...
# ✅ Batch 3, Training on rows 730000 to 735000...
# ✅ Batch 3, Training on rows 735000 to 740000...
# ✅ Batch 3, Training on rows 740000 to 745000...
# ✅ Batch 3, Training on rows 745000 to 750000...
# ✅ Batch 3, Training on rows 750000 to 755000...
# ✅ Batch 3, Training on rows 755000 to 760000...
# ✅ Batch 3, Training on rows 760000 to 765000...
# ✅ Batch 3, Training on rows 765000 to 770000...
# ✅ Batch 3, Training on rows 770000 to 775000...
# ✅ Batch 3, Training on rows 775000 to 780000...
# ✅ Batch 3, Training on rows 780000 to 785000...
# ✅ Batch 3, Training on rows 785000 to 790000...
# ✅ Batch 3, Training on rows 790000 to 795000...
# ✅ Batch 3, Training on rows 795000 to 800000...
# ✅ Batch 3, Training on rows 800000 to 805000...
# ✅ Batch 3, Training on rows 805000 to 810000...
# ✅ Batch 3, Training on rows 810000 to 815000...
# ✅ Batch 3, Training on rows 815000 to 820000...
# ✅ Batch 3, Training on rows 820000 to 825000...
# ✅ Batch 3, Training on rows 825000 to 830000...
# ✅ Batch 3, Training on rows 830000 to 835000...
# ✅ Batch 3, Training on rows 835000 to 840000...
# ✅ Batch 3, Training on rows 840000 to 845000...
# ✅ Batch 3, Training on rows 845000 to 850000...
# ✅ Batch 3, Training on rows 850000 to 855000...
# ✅ Batch 3, Training on rows 855000 to 860000...
# ✅ Batch 3, Training on rows 860000 to 865000...
# ✅ Batch 3, Training on rows 865000 to 870000...
# ✅ Batch 3, Training on rows 870000 to 875000...
# ✅ Batch 3, Training on rows 875000 to 880000...
# ✅ Batch 3, Training on rows 880000 to 885000...
# ✅ Batch 3, Training on rows 885000 to 890000...
# ✅ Batch 3, Training on rows 890000 to 895000...
# ✅ Batch 3, Training on rows 895000 to 900000...
# ✅ Batch 3, Training on rows 900000 to 905000...
# ✅ Batch 3, Training on rows 905000 to 910000...
# ✅ Batch 3, Training on rows 910000 to 915000...
# ✅ Batch 3, Training on rows 915000 to 920000...
# ✅ Batch 3, Training on rows 920000 to 925000...
# ✅ Batch 3, Training on rows 925000 to 930000...
# ✅ Batch 3, Training on rows 930000 to 935000...
# ✅ Batch 3, Training on rows 935000 to 940000...
# ✅ Batch 3, Training on rows 940000 to 945000...
# ✅ Batch 3, Training on rows 945000 to 950000...
# ✅ Batch 3, Training on rows 950000 to 955000...
# ✅ Batch 3, Training on rows 955000 to 960000...
# ✅ Batch 3, Training on rows 960000 to 965000...
# ✅ Batch 3, Training on rows 965000 to 970000...
# ✅ Batch 3, Training on rows 970000 to 975000...
# ✅ Batch 3, Training on rows 975000 to 980000...
# ✅ Batch 3, Training on rows 980000 to 985000...
# ✅ Batch 3, Training on rows 985000 to 990000...
# ✅ Batch 3, Training on rows 990000 to 995000...
# ✅ Batch 3, Training on rows 995000 to 1000000...
# ✅ Batch 3, Training on rows 1000000 to 1005000...
# ✅ Batch 3, Training on rows 1005000 to 1010000...
# ✅ Batch 3, Training on rows 1010000 to 1015000...
# ✅ Batch 3, Training on rows 1015000 to 1020000...
# ✅ Batch 3, Training on rows 1020000 to 1025000...
# ✅ Batch 3, Training on rows 1025000 to 1030000...
# ✅ Batch 3, Training on rows 1030000 to 1035000...
# ✅ Batch 3, Training on rows 1035000 to 1040000...
# ✅ Batch 3, Training on rows 1040000 to 1045000...
# ✅ Batch 3, Training on rows 1045000 to 1050000...
# ✅ Batch 3, Training on rows 1050000 to 1055000...
# ✅ Batch 3, Training on rows 1055000 to 1060000...
# ✅ Batch 3, Training on rows 1060000 to 1065000...
# ✅ Batch 3, Training on rows 1065000 to 1070000...
# ✅ Batch 3, Training on rows 1070000 to 1075000...
# ✅ Batch 3, Training on rows 1075000 to 1080000...
# ✅ Batch 3, Training on rows 1080000 to 1085000...
# ✅ Batch 3, Training on rows 1085000 to 1090000...
# ✅ Batch 3, Training on rows 1090000 to 1095000...
# ✅ Batch 3, Training on rows 1095000 to 1100000...
# ✅ Batch 3, Training on rows 1100000 to 1105000...
# ✅ Batch 3, Training on rows 1105000 to 1110000...
# ✅ Batch 3, Training on rows 1110000 to 1115000...
# ✅ Batch 3, Training on rows 1115000 to 1120000...
# ✅ Batch 3, Training on rows 1120000 to 1125000...
# ✅ Batch 3, Training on rows 1125000 to 1130000...
# ✅ Batch 3, Training on rows 1130000 to 1135000...
# ✅ Batch 3, Training on rows 1135000 to 1140000...
# ✅ Batch 3, Training on rows 1140000 to 1145000...
# ✅ Batch 3, Training on rows 1145000 to 1150000...
# ✅ Batch 3, Training on rows 1150000 to 1155000...
# ✅ Batch 3, Training on rows 1155000 to 1160000...
# ✅ Batch 3, Training on rows 1160000 to 1165000...
# ✅ Batch 3, Training on rows 1165000 to 1170000...
# ✅ Batch 3, Training on rows 1170000 to 1175000...
# ✅ Batch 3, Training on rows 1175000 to 1180000...
# ✅ Batch 3, Training on rows 1180000 to 1185000...
# ✅ Batch 3, Training on rows 1185000 to 1190000...
# ✅ Batch 3, Training on rows 1190000 to 1195000...
# ✅ Batch 3, Training on rows 1195000 to 1200000...
# ✅ Batch 3, Training on rows 1200000 to 1205000...
# ✅ Batch 3, Training on rows 1205000 to 1210000...
# ✅ Batch 3, Training on rows 1210000 to 1215000...
# ✅ Batch 3, Training on rows 1215000 to 1220000...
# ✅ Batch 3, Training on rows 1220000 to 1225000...
# ✅ Batch 3, Training on rows 1225000 to 1230000...
# ✅ Batch 3, Training on rows 1230000 to 1235000...
# ✅ Batch 3, Training on rows 1235000 to 1240000...
# ✅ Batch 3, Training on rows 1240000 to 1245000...
# ✅ Batch 3, Training on rows 1245000 to 1250000...
# ✅ Batch 3, Training on rows 1250000 to 1255000...
# ✅ Batch 3, Training on rows 1255000 to 1260000...
# ✅ Batch 3, Training on rows 1260000 to 1265000...
# ✅ Batch 3, Training on rows 1265000 to 1270000...
# ✅ Batch 3, Training on rows 1270000 to 1275000...
# ✅ Batch 3, Training on rows 1275000 to 1280000...
# ✅ Batch 3, Training on rows 1280000 to 1285000...
# ✅ Batch 3, Training on rows 1285000 to 1290000...
# ✅ Batch 3, Training on rows 1290000 to 1295000...
# ✅ Batch 3, Training on rows 1295000 to 1300000...
# ✅ Batch 3, Training on rows 1300000 to 1305000...
# ✅ Batch 3, Training on rows 1305000 to 1310000...
# ✅ Batch 3, Training on rows 1310000 to 1315000...
# ✅ Batch 3, Training on rows 1315000 to 1320000...
# ✅ Batch 3, Training on rows 1320000 to 1325000...
# ✅ Batch 3, Training on rows 1325000 to 1330000...
# ✅ Batch 3, Training on rows 1330000 to 1335000...
# ✅ Batch 3, Training on rows 1335000 to 1340000...
# ✅ Batch 3, Training on rows 1340000 to 1345000...
# ✅ Batch 3, Training on rows 1345000 to 1350000...
# ✅ Batch 3, Training on rows 1350000 to 1355000...
# ✅ Batch 3, Training on rows 1355000 to 1360000...
# ✅ Batch 3, Training on rows 1360000 to 1365000...
# ✅ Batch 3, Training on rows 1365000 to 1370000...
# ✅ Batch 3, Training on rows 1370000 to 1375000...
# ✅ Batch 3, Training on rows 1375000 to 1380000...
# ✅ Batch 3, Training on rows 1380000 to 1385000...
# ✅ Batch 3, Training on rows 1385000 to 1390000...
# ✅ Batch 3, Training on rows 1390000 to 1395000...
# ✅ Batch 3, Training on rows 1395000 to 1400000...

# %%
# 📌 Make Predictions
y_pred_xgb = xgb_model.predict(X_test)


# 📌 Evaluate Models
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mape_xgb = (mae_xgb / y_test.mean()) * 100


print(f"\n📊 XGBoost MAE: ${mae_xgb:.2f}, MAPE: {mape_xgb:.2f}%")
# Out:
# 📊 XGBoost MAE: $73.06, MAPE: 27.56%

# %%
# 📌 Evaluate Blended Model
mae_blended = mean_absolute_error(y_test, y_pred_blended)
mape_blended = (mae_blended / y_test.mean()) * 100
print(f"\n📊 Blended Model MAE: ${mae_blended:.2f}, MAPE: {mape_blended:.2f}%")
